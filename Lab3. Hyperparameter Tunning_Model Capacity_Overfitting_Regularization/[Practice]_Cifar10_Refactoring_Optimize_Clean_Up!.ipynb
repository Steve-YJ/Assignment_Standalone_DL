# %% [markdown]
# <a href="https://colab.research.google.com/github/Steve-YJ/Assignment_Standalone_DL/blob/master/%5BPractice%5D_Cifar10_Refactoring_Optimize_Clean_Up!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lec3. Practice
# # CIFAR-10 Classifier: Hyperparameter Tunning!!
# * Training with PyTorch
# * 20.09.04.Fri. pm 9:00
# * Review >>> 20.09.07.mon. pm 6:25
# * Again >>> 20.09.22.Ture. pm 4:00
# <br><br>
# * Reference: https://github.com/heartcored98/Standalone-DeepLearning/blob/master/Lec3/Lab4_write_pretty_DL_code.ipynb

# %% [markdown]
# > <code>학습 Flow</code> -20.09.16.wed-<br>
# > Import Library<br>
# > Data Preparation<br>
# > Model Architecture<br>
# > Define Exp<br>
# > Experiment!<br>

# %% [markdown]
# # Import Library

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# * Train, Val, Test Loader를 따로 구현한다

# %%
transforms = transforms.Compose([
                                 transforms.ToTensor(),
                                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize a tensor image with mean and standard deviation
     ])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transforms)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transforms)

# what is partition?
partition = {'train': trainset, 'val':valset, 'test':testset}
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Inspect Dataset

# %%
# 필요시 사용

"""
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))

print(type(images), images.shape)
print(type(labels), labels.shape, labels)  # 각각의 클래스

"""
# Out:
# "\nimport matplotlib.pyplot as plt\nimport numpy as np\n\n# functions to show an image\n\n\ndef imshow(img):\n    img = img / 2 + 0.5     # unnormalize\n    npimg = img.numpy()\n    plt.imshow(np.transpose(npimg, (1, 2, 0)))\n    plt.show()\n\n\n# get some random training images\ndataiter = iter(trainloader)\nimages, labels = dataiter.next()\n\n# show images\nimshow(torchvision.utils.make_grid(images))\n# print labels\nprint(' '.join('%5s' % classes[labels[j]] for j in range(4)))\n\nprint(type(images), images.shape)\nprint(type(labels), labels.shape, labels)  # 각각의 클래스\n\n"

# %% [markdown]
# # Model Architecture
# * dropout, batch-norm, xavier_initialization등을 추가해준다

# %%
import torch.nn as nn
import torch.nn.functional as F

class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hid_dim, n_layer, act, dropout, use_bn, use_xavier):
        super(MLP, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.n_layer = n_layer
        self.act = act
        # add dropout, use_bn, use_xavier
        self.dropout = dropout
        self.use_bn = use_bn
        self.use_xavier = use_xavier
        
        # ===== Create Linear Layers ==== #
        self.fc1 = nn.Linear(self.in_dim, self.hid_dim)
        self.linears = nn.ModuleList()  # 여러개의 hid_layer 구성. nn.ModuleList()
        self.bns = nn.ModuleList()
        for i in range(self.n_layer-1):
            self.linears.append(nn.Linear(self.hid_dim, self.hid_dim))
            if self.use_bn:
                self.bns.append(nn.BatchNorm1d(self.hid_dim))  # Applies Batch Normalization over a 2D or 3D input (a mini-batch of 1D inputs with optional additional channel dimension) as described in the paper

        self.fc2 = nn.Linear(self.hid_dim, self.out_dim)

        # ===== Create Activation Funciton ====== #
        if self.act == 'relu':
            self.act = nn.ReLU() 
        elif self.act == 'tanh':
            self.act = nn.Tanh()
        elif self.act == 'sigmoid':
            self.act = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected!')

        # ===== Create Regularization Layer ===== #
        self.dropout = nn.Dropout(self.dropout)
        if self.use_xavier:
            self.xavier_init()

    def forward(self, x):
        x = self.act(self.fc1(x))
        for i in range(len(self.linears)):
            x = self.act(self.linears[i](x))
            x = self.bns[i](x)
            x = self.dropout(x)
        x = self.fc2(x)
        return x

    def xavier_init(self):
        for linear in self.linears:
            nn.init.xavier_normal_(linear.weight)
            linear.bias.data.fill_(0.01)

net = MLP(3072, 10, 100, 4, 'relu', 0.1, True, True)
print(net)
# Out:
# MLP(
#   (fc1): Linear(in_features=3072, out_features=100, bias=True)
#   (linears): ModuleList(
#     (0): Linear(in_features=100, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=100, bias=True)
#     (2): Linear(in_features=100, out_features=100, bias=True)
#   )
#   (bns): ModuleList(
#     (0): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (act): ReLU()
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# # Train, Validate, Test and Experiment

# %%
def train(net, partition, optimizer, criterion, args):
    # train 함수 내에 trainloader 정의
    trainloader = torch.utils.data.DataLoader(partition['train'],
                                              batch_size = args.train_batch_size,
                                              shuffle=True,
                                              num_workers=2)
    
    net.train()
    optimizer.zero_grad()

    correct = 0
    total = 0
    train_loss = 0.0

    for i, data in enumerate(trainloader, 0):  # data loader를 돌면서...!
        # get the inputs
        inputs, labels = data
        inputs = inputs.view(-1, 3072)  # 입력값의 형상(shape)을 입력 레이어의 형상과 같게 만들어준다
        inputs = inputs.cuda()  # GPU에 데이터를 올려준다
        labels = labels.cuda()
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        # print('print predicted: ', predicted.shape, predicted)
        # print('ptin labels: ', labels)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'],
                                            batch_size=args.test_batch_size,
                                            shuffle=False,
                                            num_workers=2)
    net.eval()

    correct = 0
    total = 0
    val_loss = 0

    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'],
                                            batch_size=args.test_batch_size,
                                            shuffle=False,
                                            num_workers=2)
    net.eval()

    correct = 0
    total = 0
    test_loss = 0
    with torch.no_grad():
        for data, labels in testloader:
            images = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()
            outputs = net(images)

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_loss, test_acc

# %%
def experiment(partition, args):
    import time
    net = MLP(args.in_dim, args.out_dim, args.hid_dim, args.n_layer, args.act, args.dropout, args.use_bn, args.use_xavier)
    net.cuda()

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')

    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(net, partition, criterion, args)
        te = time.time()
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.2f}/{:2.2f}, Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
    test_acc = test(net, partition, args)
    return train_loss, val_loss, train_acc, val_acc, test_acc

# %% [markdown]
# # Experiment

# %%
import argparse

# ===== Random Seed initialization ===== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")

# ===== Model Capacity ===== #
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

# ===== Regularization ===== #
args.dropout = 0.1
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ===== Opitmizer & Training ===== #
args.optim = 'SGD'  # RMSprop, SGD, RMSprop, ADAM....
args.lr = 0.00005
args.epoch = 20

args.train_batch_size = 256
args.test_batch_size = 1024

# ===== Experiment Variable ===== #
name_var1 = 'n_layer'
name_var2 = 'hid_dim'
list_var1 = [3, 5, 10, 20, 50, 100]
list_var2 = [300, 500, 700, 1000]

for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
        result = experiment(partition, args)
# Out:
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=3, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 25.57/35.13, Loss(train/val) 2.08/0.00, Took 5.99 sec
# Epoch 1, Acc(train/val): 36.35/39.99, Loss(train/val) 1.80/0.00, Took 5.95 sec
# Epoch 2, Acc(train/val): 39.95/42.07, Loss(train/val) 1.70/0.00, Took 5.97 sec
# Epoch 3, Acc(train/val): 42.40/43.29, Loss(train/val) 1.64/0.00, Took 5.97 sec
# Epoch 4, Acc(train/val): 44.38/44.08, Loss(train/val) 1.58/0.00, Took 5.91 sec
# Epoch 5, Acc(train/val): 46.01/45.90, Loss(train/val) 1.54/0.00, Took 5.98 sec
# Epoch 6, Acc(train/val): 47.54/46.25, Loss(train/val) 1.50/0.00, Took 5.94 sec
# Epoch 7, Acc(train/val): 49.10/46.78, Loss(train/val) 1.46/0.00, Took 5.95 sec
# Epoch 8, Acc(train/val): 49.98/47.29, Loss(train/val) 1.43/0.00, Took 5.96 sec
# Epoch 9, Acc(train/val): 51.03/47.86, Loss(train/val) 1.40/0.00, Took 6.07 sec
# Epoch 10, Acc(train/val): 51.61/48.02, Loss(train/val) 1.38/0.00, Took 6.08 sec
# Epoch 11, Acc(train/val): 52.56/47.95, Loss(train/val) 1.36/0.00, Took 6.12 sec
# Epoch 12, Acc(train/val): 53.33/48.36, Loss(train/val) 1.33/0.00, Took 6.01 sec
# Epoch 13, Acc(train/val): 54.47/48.63, Loss(train/val) 1.31/0.00, Took 6.05 sec
# Epoch 14, Acc(train/val): 55.06/48.77, Loss(train/val) 1.29/0.00, Took 5.88 sec
# Epoch 15, Acc(train/val): 55.77/49.13, Loss(train/val) 1.27/0.00, Took 5.98 sec
# Epoch 16, Acc(train/val): 56.18/48.56, Loss(train/val) 1.26/0.00, Took 5.99 sec
# Epoch 17, Acc(train/val): 56.91/49.66, Loss(train/val) 1.23/0.00, Took 5.98 sec
# Epoch 18, Acc(train/val): 57.84/49.22, Loss(train/val) 1.21/0.00, Took 5.92 sec
# Epoch 19, Acc(train/val): 58.23/49.20, Loss(train/val) 1.20/0.00, Took 5.94 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=3, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 26.04/36.21, Loss(train/val) 2.06/0.00, Took 6.02 sec
# Epoch 1, Acc(train/val): 37.65/40.73, Loss(train/val) 1.77/0.00, Took 5.99 sec
# Epoch 2, Acc(train/val): 42.05/42.77, Loss(train/val) 1.65/0.00, Took 6.00 sec
# Epoch 3, Acc(train/val): 44.55/44.51, Loss(train/val) 1.58/0.00, Took 5.98 sec
# Epoch 4, Acc(train/val): 46.67/45.38, Loss(train/val) 1.52/0.00, Took 5.96 sec
# Epoch 5, Acc(train/val): 48.41/46.83, Loss(train/val) 1.48/0.00, Took 5.97 sec
# Epoch 6, Acc(train/val): 50.14/47.56, Loss(train/val) 1.44/0.00, Took 6.03 sec
# Epoch 7, Acc(train/val): 51.18/47.38, Loss(train/val) 1.40/0.00, Took 5.98 sec
# Epoch 8, Acc(train/val): 52.18/48.73, Loss(train/val) 1.37/0.00, Took 5.91 sec
# Epoch 9, Acc(train/val): 53.29/47.87, Loss(train/val) 1.34/0.00, Took 5.98 sec
# Epoch 10, Acc(train/val): 54.64/48.86, Loss(train/val) 1.31/0.00, Took 6.00 sec
# Epoch 11, Acc(train/val): 55.45/48.86, Loss(train/val) 1.28/0.00, Took 5.97 sec
# Epoch 12, Acc(train/val): 56.48/49.78, Loss(train/val) 1.25/0.00, Took 5.88 sec
# Epoch 13, Acc(train/val): 57.21/49.52, Loss(train/val) 1.23/0.00, Took 5.94 sec
# Epoch 14, Acc(train/val): 58.22/50.82, Loss(train/val) 1.20/0.00, Took 6.02 sec
# Epoch 15, Acc(train/val): 59.50/50.14, Loss(train/val) 1.18/0.00, Took 5.93 sec
# Epoch 16, Acc(train/val): 59.99/50.59, Loss(train/val) 1.16/0.00, Took 5.93 sec
# Epoch 17, Acc(train/val): 60.37/50.24, Loss(train/val) 1.14/0.00, Took 5.91 sec
# Epoch 18, Acc(train/val): 60.98/50.33, Loss(train/val) 1.13/0.00, Took 6.03 sec
# Epoch 19, Acc(train/val): 61.63/50.33, Loss(train/val) 1.10/0.00, Took 5.99 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=3, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 27.20/37.15, Loss(train/val) 2.04/0.00, Took 5.93 sec
# Epoch 1, Acc(train/val): 39.28/42.04, Loss(train/val) 1.73/0.00, Took 5.98 sec
# Epoch 2, Acc(train/val): 43.48/44.08, Loss(train/val) 1.61/0.00, Took 6.01 sec
# Epoch 3, Acc(train/val): 46.08/45.78, Loss(train/val) 1.54/0.00, Took 5.98 sec
# Epoch 4, Acc(train/val): 48.25/46.74, Loss(train/val) 1.48/0.00, Took 5.98 sec
# Epoch 5, Acc(train/val): 49.92/47.60, Loss(train/val) 1.43/0.00, Took 5.95 sec
# Epoch 6, Acc(train/val): 51.69/48.34, Loss(train/val) 1.39/0.00, Took 5.99 sec
# Epoch 7, Acc(train/val): 53.13/49.14, Loss(train/val) 1.35/0.00, Took 5.94 sec
# Epoch 8, Acc(train/val): 54.67/49.38, Loss(train/val) 1.31/0.00, Took 5.97 sec
# Epoch 9, Acc(train/val): 56.04/49.80, Loss(train/val) 1.27/0.00, Took 5.98 sec
# Epoch 10, Acc(train/val): 57.27/50.07, Loss(train/val) 1.24/0.00, Took 5.97 sec
# Epoch 11, Acc(train/val): 58.38/50.22, Loss(train/val) 1.21/0.00, Took 6.00 sec
# Epoch 12, Acc(train/val): 59.13/50.14, Loss(train/val) 1.18/0.00, Took 6.05 sec
# Epoch 13, Acc(train/val): 60.74/50.25, Loss(train/val) 1.15/0.00, Took 5.97 sec
# Epoch 14, Acc(train/val): 61.56/50.94, Loss(train/val) 1.12/0.00, Took 6.00 sec
# Epoch 15, Acc(train/val): 62.53/50.24, Loss(train/val) 1.10/0.00, Took 5.99 sec
# Epoch 16, Acc(train/val): 63.23/50.10, Loss(train/val) 1.07/0.00, Took 5.89 sec
# Epoch 17, Acc(train/val): 64.09/50.54, Loss(train/val) 1.05/0.00, Took 5.95 sec
# Epoch 18, Acc(train/val): 65.09/50.32, Loss(train/val) 1.03/0.00, Took 5.99 sec
# Epoch 19, Acc(train/val): 66.33/50.60, Loss(train/val) 1.00/0.00, Took 5.96 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=3, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 27.63/37.61, Loss(train/val) 2.03/0.00, Took 6.01 sec
# Epoch 1, Acc(train/val): 40.30/43.27, Loss(train/val) 1.70/0.00, Took 6.15 sec
# Epoch 2, Acc(train/val): 44.90/44.44, Loss(train/val) 1.58/0.00, Took 6.06 sec
# Epoch 3, Acc(train/val): 47.76/46.77, Loss(train/val) 1.50/0.00, Took 5.94 sec
# Epoch 4, Acc(train/val): 50.02/47.04, Loss(train/val) 1.44/0.00, Took 5.91 sec
# Epoch 5, Acc(train/val): 51.84/47.77, Loss(train/val) 1.39/0.00, Took 6.03 sec
# Epoch 6, Acc(train/val): 53.91/48.78, Loss(train/val) 1.34/0.00, Took 5.96 sec
# Epoch 7, Acc(train/val): 55.19/48.58, Loss(train/val) 1.30/0.00, Took 5.91 sec
# Epoch 8, Acc(train/val): 56.48/49.07, Loss(train/val) 1.25/0.00, Took 5.94 sec
# Epoch 9, Acc(train/val): 58.03/49.00, Loss(train/val) 1.22/0.00, Took 5.94 sec
# Epoch 10, Acc(train/val): 59.34/49.58, Loss(train/val) 1.18/0.00, Took 6.00 sec
# Epoch 11, Acc(train/val): 61.04/50.06, Loss(train/val) 1.14/0.00, Took 5.96 sec
# Epoch 12, Acc(train/val): 62.41/50.46, Loss(train/val) 1.11/0.00, Took 5.96 sec
# Epoch 13, Acc(train/val): 63.70/50.90, Loss(train/val) 1.07/0.00, Took 5.99 sec
# Epoch 14, Acc(train/val): 64.74/51.21, Loss(train/val) 1.04/0.00, Took 6.03 sec
# Epoch 15, Acc(train/val): 66.23/51.51, Loss(train/val) 1.01/0.00, Took 5.97 sec
# Epoch 16, Acc(train/val): 67.45/51.88, Loss(train/val) 0.98/0.00, Took 5.95 sec
# Epoch 17, Acc(train/val): 68.30/51.51, Loss(train/val) 0.95/0.00, Took 5.96 sec
# Epoch 18, Acc(train/val): 69.61/51.62, Loss(train/val) 0.91/0.00, Took 5.92 sec
# Epoch 19, Acc(train/val): 70.78/51.63, Loss(train/val) 0.88/0.00, Took 5.98 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=5, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 21.47/31.99, Loss(train/val) 2.18/0.00, Took 6.02 sec
# Epoch 1, Acc(train/val): 32.03/37.16, Loss(train/val) 1.91/0.00, Took 6.02 sec
# Epoch 2, Acc(train/val): 36.82/39.64, Loss(train/val) 1.78/0.00, Took 6.05 sec
# Epoch 3, Acc(train/val): 39.28/41.58, Loss(train/val) 1.71/0.00, Took 6.12 sec
# Epoch 4, Acc(train/val): 41.28/42.54, Loss(train/val) 1.65/0.00, Took 6.06 sec
# Epoch 5, Acc(train/val): 42.81/43.69, Loss(train/val) 1.61/0.00, Took 6.03 sec
# Epoch 6, Acc(train/val): 44.45/44.48, Loss(train/val) 1.57/0.00, Took 6.13 sec
# Epoch 7, Acc(train/val): 45.24/45.82, Loss(train/val) 1.54/0.00, Took 5.97 sec
# Epoch 8, Acc(train/val): 46.34/46.17, Loss(train/val) 1.51/0.00, Took 6.07 sec
# Epoch 9, Acc(train/val): 47.55/46.51, Loss(train/val) 1.48/0.00, Took 6.04 sec
# Epoch 10, Acc(train/val): 48.38/47.10, Loss(train/val) 1.46/0.00, Took 6.06 sec
# Epoch 11, Acc(train/val): 49.38/47.69, Loss(train/val) 1.43/0.00, Took 6.12 sec
# Epoch 12, Acc(train/val): 50.45/48.04, Loss(train/val) 1.41/0.00, Took 6.06 sec
# Epoch 13, Acc(train/val): 50.57/48.32, Loss(train/val) 1.39/0.00, Took 6.07 sec
# Epoch 14, Acc(train/val): 51.40/48.30, Loss(train/val) 1.37/0.00, Took 6.01 sec
# Epoch 15, Acc(train/val): 51.84/48.17, Loss(train/val) 1.35/0.00, Took 6.13 sec
# Epoch 16, Acc(train/val): 52.33/48.15, Loss(train/val) 1.34/0.00, Took 6.15 sec
# Epoch 17, Acc(train/val): 53.02/48.80, Loss(train/val) 1.32/0.00, Took 6.07 sec
# Epoch 18, Acc(train/val): 53.81/48.19, Loss(train/val) 1.30/0.00, Took 6.02 sec
# Epoch 19, Acc(train/val): 54.23/49.37, Loss(train/val) 1.29/0.00, Took 6.03 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=5, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 23.25/33.78, Loss(train/val) 2.15/0.00, Took 6.03 sec
# Epoch 1, Acc(train/val): 34.24/39.74, Loss(train/val) 1.85/0.00, Took 6.03 sec
# Epoch 2, Acc(train/val): 38.96/41.72, Loss(train/val) 1.72/0.00, Took 6.10 sec
# Epoch 3, Acc(train/val): 41.57/43.83, Loss(train/val) 1.65/0.00, Took 5.99 sec
# Epoch 4, Acc(train/val): 43.69/44.54, Loss(train/val) 1.59/0.00, Took 6.04 sec
# Epoch 5, Acc(train/val): 45.16/45.55, Loss(train/val) 1.55/0.00, Took 6.10 sec
# Epoch 6, Acc(train/val): 46.77/45.67, Loss(train/val) 1.51/0.00, Took 6.10 sec
# Epoch 7, Acc(train/val): 47.78/46.84, Loss(train/val) 1.48/0.00, Took 6.09 sec
# Epoch 8, Acc(train/val): 49.08/47.66, Loss(train/val) 1.44/0.00, Took 6.00 sec
# Epoch 9, Acc(train/val): 50.14/47.89, Loss(train/val) 1.41/0.00, Took 6.06 sec
# Epoch 10, Acc(train/val): 51.16/48.25, Loss(train/val) 1.38/0.00, Took 6.05 sec
# Epoch 11, Acc(train/val): 51.94/48.78, Loss(train/val) 1.35/0.00, Took 6.14 sec
# Epoch 12, Acc(train/val): 52.66/48.71, Loss(train/val) 1.34/0.00, Took 6.23 sec
# Epoch 13, Acc(train/val): 53.56/49.49, Loss(train/val) 1.31/0.00, Took 6.05 sec
# Epoch 14, Acc(train/val): 54.63/49.09, Loss(train/val) 1.29/0.00, Took 6.04 sec
# Epoch 15, Acc(train/val): 55.15/49.34, Loss(train/val) 1.27/0.00, Took 6.06 sec
# Epoch 16, Acc(train/val): 55.99/48.52, Loss(train/val) 1.25/0.00, Took 6.08 sec
# Epoch 17, Acc(train/val): 56.69/50.27, Loss(train/val) 1.22/0.00, Took 6.05 sec
# Epoch 18, Acc(train/val): 57.37/49.64, Loss(train/val) 1.20/0.00, Took 6.11 sec
# Epoch 19, Acc(train/val): 58.17/49.97, Loss(train/val) 1.19/0.00, Took 6.05 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=5, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 23.59/33.17, Loss(train/val) 2.13/0.00, Took 6.04 sec
# Epoch 1, Acc(train/val): 35.69/39.55, Loss(train/val) 1.81/0.00, Took 6.08 sec
# Epoch 2, Acc(train/val): 40.38/42.10, Loss(train/val) 1.68/0.00, Took 6.13 sec
# Epoch 3, Acc(train/val): 43.12/44.32, Loss(train/val) 1.61/0.00, Took 6.08 sec
# Epoch 4, Acc(train/val): 45.62/45.16, Loss(train/val) 1.54/0.00, Took 6.03 sec
# Epoch 5, Acc(train/val): 47.22/46.29, Loss(train/val) 1.49/0.00, Took 6.14 sec
# Epoch 6, Acc(train/val): 48.79/47.25, Loss(train/val) 1.45/0.00, Took 6.06 sec
# Epoch 7, Acc(train/val): 50.22/47.63, Loss(train/val) 1.41/0.00, Took 6.07 sec
# Epoch 8, Acc(train/val): 51.39/48.62, Loss(train/val) 1.37/0.00, Took 6.14 sec
# Epoch 9, Acc(train/val): 52.40/48.70, Loss(train/val) 1.34/0.00, Took 6.06 sec
# Epoch 10, Acc(train/val): 53.36/49.48, Loss(train/val) 1.31/0.00, Took 6.03 sec
# Epoch 11, Acc(train/val): 54.38/49.25, Loss(train/val) 1.28/0.00, Took 6.06 sec
# Epoch 12, Acc(train/val): 55.56/49.57, Loss(train/val) 1.26/0.00, Took 5.99 sec
# Epoch 13, Acc(train/val): 56.62/49.66, Loss(train/val) 1.23/0.00, Took 6.07 sec
# Epoch 14, Acc(train/val): 57.15/49.94, Loss(train/val) 1.20/0.00, Took 6.08 sec
# Epoch 15, Acc(train/val): 58.44/49.96, Loss(train/val) 1.18/0.00, Took 6.08 sec
# Epoch 16, Acc(train/val): 59.40/50.17, Loss(train/val) 1.16/0.00, Took 6.05 sec
# Epoch 17, Acc(train/val): 60.33/50.46, Loss(train/val) 1.13/0.00, Took 5.99 sec
# Epoch 18, Acc(train/val): 60.80/50.50, Loss(train/val) 1.11/0.00, Took 6.06 sec
# Epoch 19, Acc(train/val): 61.82/50.86, Loss(train/val) 1.09/0.00, Took 6.02 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=5, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 25.22/36.14, Loss(train/val) 2.08/0.00, Took 6.08 sec
# Epoch 1, Acc(train/val): 37.15/40.90, Loss(train/val) 1.77/0.00, Took 6.09 sec
# Epoch 2, Acc(train/val): 41.42/42.89, Loss(train/val) 1.66/0.00, Took 6.08 sec
# Epoch 3, Acc(train/val): 44.56/44.96, Loss(train/val) 1.57/0.00, Took 6.07 sec
# Epoch 4, Acc(train/val): 46.94/46.07, Loss(train/val) 1.51/0.00, Took 6.06 sec
# Epoch 5, Acc(train/val): 48.94/46.82, Loss(train/val) 1.45/0.00, Took 6.06 sec
# Epoch 6, Acc(train/val): 50.39/47.66, Loss(train/val) 1.40/0.00, Took 6.11 sec
# Epoch 7, Acc(train/val): 52.24/48.25, Loss(train/val) 1.36/0.00, Took 6.01 sec
# Epoch 8, Acc(train/val): 53.96/49.03, Loss(train/val) 1.32/0.00, Took 6.05 sec
# Epoch 9, Acc(train/val): 55.34/49.29, Loss(train/val) 1.27/0.00, Took 6.14 sec
# Epoch 10, Acc(train/val): 56.33/49.79, Loss(train/val) 1.24/0.00, Took 6.07 sec
# Epoch 11, Acc(train/val): 58.04/49.18, Loss(train/val) 1.20/0.00, Took 6.04 sec
# Epoch 12, Acc(train/val): 58.82/50.16, Loss(train/val) 1.18/0.00, Took 6.10 sec
# Epoch 13, Acc(train/val): 60.05/50.35, Loss(train/val) 1.14/0.00, Took 6.08 sec
# Epoch 14, Acc(train/val): 60.89/50.59, Loss(train/val) 1.12/0.00, Took 5.98 sec
# Epoch 15, Acc(train/val): 62.23/50.59, Loss(train/val) 1.09/0.00, Took 6.02 sec
# Epoch 16, Acc(train/val): 63.04/50.74, Loss(train/val) 1.06/0.00, Took 6.05 sec
# Epoch 17, Acc(train/val): 64.22/50.58, Loss(train/val) 1.02/0.00, Took 6.15 sec
# Epoch 18, Acc(train/val): 65.17/50.80, Loss(train/val) 1.00/0.00, Took 6.03 sec
# Epoch 19, Acc(train/val): 66.39/51.19, Loss(train/val) 0.97/0.00, Took 6.11 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=5e-05, n_layer=10, optim='SGD', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 12.44/18.14, Loss(train/val) 2.39/0.00, Took 6.35 sec
# Epoch 1, Acc(train/val): 18.14/24.66, Loss(train/val) 2.23/0.00, Took 6.26 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0ffa88a56642> in <module>()
#      40         setattr(args, name_var2, var2)
#      41         print(args)
# ---> 42         result = experiment(partition, args)
#
# <ipython-input-7-882f69e0bc5e> in experiment(partition, args)
#      16     for epoch in range(args.epoch):  # loop over the dataset multiple times
#      17         ts = time.time()
# ---> 18         net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
#      19         val_loss, val_acc = validate(net, partition, criterion, args)
#      20         te = time.time()
#
# <ipython-input-4-b5a10c4eae4c> in train(net, partition, optimizer, criterion, args)
#      15     for i, data in enumerate(trainloader, 0):  # data loader를 돌면서...!
#      16         # get the inputs
# ---> 17         inputs, labels = data
#      18         inputs = inputs.view(-1, 3072)  # 입력값의 형상(shape)을 입력 레이어의 형상과 같게 만들어준다
#      19         inputs = inputs.cuda()  # GPU에 데이터를 올려준다
#
# KeyboardInterrupt:

# %% [markdown]
# * Tunning
#     * Change Optimizer: SGD to Adam
#     * 좋다니깐...!

# %%
import argparse

# ===== Random Seed initialization ===== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")

# ===== Model Capacity ===== #
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

# ===== Regularization ===== #
args.dropout = 0.1
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ===== Opitmizer & Training ===== #
args.optim = 'Adam'  # RMSprop, SGD, RMSprop, ADAM....
args.lr = 0.00001 # learning rate도 0.00001로 변경...!
args.epoch = 20

args.train_batch_size = 256
args.test_batch_size = 1024

# ===== Experiment Variable ===== #
name_var1 = 'n_layer'
name_var2 = 'hid_dim'
list_var1 = [3, 5, 10, 20, 50, 100]
list_var2 = [300, 500, 700, 1000]

for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)
        result = experiment(partition, args)

"""
##### Optimizer만 변경해도 성능이 폭발적으로 증가할까? #####

"""
# Out:
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 29.53/37.77, Loss(train/val) 1.99/0.00, Took 5.84 sec
# Epoch 1, Acc(train/val): 39.13/41.90, Loss(train/val) 1.73/0.00, Took 5.65 sec
# Epoch 2, Acc(train/val): 42.73/41.15, Loss(train/val) 1.64/0.00, Took 5.39 sec
# Epoch 3, Acc(train/val): 43.89/43.96, Loss(train/val) 1.59/0.00, Took 5.50 sec
# Epoch 4, Acc(train/val): 45.66/43.98, Loss(train/val) 1.55/0.00, Took 5.55 sec
# Epoch 5, Acc(train/val): 46.88/44.63, Loss(train/val) 1.52/0.00, Took 5.53 sec
# Epoch 6, Acc(train/val): 47.66/43.97, Loss(train/val) 1.49/0.00, Took 5.28 sec
# Epoch 7, Acc(train/val): 47.29/44.90, Loss(train/val) 1.49/0.00, Took 5.41 sec
# Epoch 8, Acc(train/val): 48.98/46.09, Loss(train/val) 1.45/0.00, Took 5.63 sec
# Epoch 9, Acc(train/val): 50.15/45.42, Loss(train/val) 1.42/0.00, Took 5.55 sec
# Epoch 10, Acc(train/val): 50.52/46.36, Loss(train/val) 1.40/0.00, Took 5.44 sec
# Epoch 11, Acc(train/val): 50.93/46.10, Loss(train/val) 1.39/0.00, Took 5.46 sec
# Epoch 12, Acc(train/val): 51.40/44.95, Loss(train/val) 1.38/0.00, Took 5.51 sec
# Epoch 13, Acc(train/val): 51.61/46.13, Loss(train/val) 1.38/0.00, Took 5.69 sec
# Epoch 14, Acc(train/val): 52.50/47.66, Loss(train/val) 1.37/0.00, Took 5.44 sec
# Epoch 15, Acc(train/val): 54.17/48.37, Loss(train/val) 1.31/0.00, Took 5.54 sec
# Epoch 16, Acc(train/val): 55.19/46.88, Loss(train/val) 1.28/0.00, Took 5.68 sec
# Epoch 17, Acc(train/val): 54.97/47.06, Loss(train/val) 1.29/0.00, Took 5.56 sec
# Epoch 18, Acc(train/val): 55.03/47.75, Loss(train/val) 1.28/0.00, Took 5.47 sec
# Epoch 19, Acc(train/val): 55.26/47.56, Loss(train/val) 1.26/0.00, Took 5.27 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 31.44/38.95, Loss(train/val) 1.93/0.00, Took 5.58 sec
# Epoch 1, Acc(train/val): 41.19/41.16, Loss(train/val) 1.68/0.00, Took 5.27 sec
# Epoch 2, Acc(train/val): 43.92/41.78, Loss(train/val) 1.59/0.00, Took 5.21 sec
# Epoch 3, Acc(train/val): 44.75/43.11, Loss(train/val) 1.57/0.00, Took 5.60 sec
# Epoch 4, Acc(train/val): 46.93/44.17, Loss(train/val) 1.52/0.00, Took 5.61 sec
# Epoch 5, Acc(train/val): 46.38/43.54, Loss(train/val) 1.52/0.00, Took 5.67 sec
# Epoch 6, Acc(train/val): 48.63/45.71, Loss(train/val) 1.47/0.00, Took 5.69 sec
# Epoch 7, Acc(train/val): 49.41/44.59, Loss(train/val) 1.44/0.00, Took 5.65 sec
# Epoch 8, Acc(train/val): 49.88/47.10, Loss(train/val) 1.43/0.00, Took 5.74 sec
# Epoch 9, Acc(train/val): 52.49/48.16, Loss(train/val) 1.35/0.00, Took 5.57 sec
# Epoch 10, Acc(train/val): 53.94/46.60, Loss(train/val) 1.31/0.00, Took 5.52 sec
# Epoch 11, Acc(train/val): 52.98/45.76, Loss(train/val) 1.34/0.00, Took 5.77 sec
# Epoch 12, Acc(train/val): 54.24/47.75, Loss(train/val) 1.30/0.00, Took 5.54 sec
# Epoch 13, Acc(train/val): 55.49/48.59, Loss(train/val) 1.27/0.00, Took 5.49 sec
# Epoch 14, Acc(train/val): 56.38/48.65, Loss(train/val) 1.25/0.00, Took 5.19 sec
# Epoch 15, Acc(train/val): 57.85/48.29, Loss(train/val) 1.21/0.00, Took 5.39 sec
# Epoch 16, Acc(train/val): 57.51/48.02, Loss(train/val) 1.22/0.00, Took 5.41 sec
# Epoch 17, Acc(train/val): 57.77/48.53, Loss(train/val) 1.21/0.00, Took 5.68 sec
# Epoch 18, Acc(train/val): 59.15/49.23, Loss(train/val) 1.17/0.00, Took 5.68 sec
# Epoch 19, Acc(train/val): 60.01/49.81, Loss(train/val) 1.15/0.00, Took 5.75 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 33.24/39.01, Loss(train/val) 1.88/0.00, Took 5.59 sec
# Epoch 1, Acc(train/val): 41.05/41.54, Loss(train/val) 1.67/0.00, Took 5.60 sec
# Epoch 2, Acc(train/val): 43.86/41.44, Loss(train/val) 1.60/0.00, Took 5.65 sec
# Epoch 3, Acc(train/val): 43.63/40.30, Loss(train/val) 1.60/0.00, Took 5.81 sec
# Epoch 4, Acc(train/val): 44.55/43.67, Loss(train/val) 1.57/0.00, Took 5.93 sec
# Epoch 5, Acc(train/val): 47.66/45.41, Loss(train/val) 1.49/0.00, Took 5.63 sec
# Epoch 6, Acc(train/val): 48.87/46.43, Loss(train/val) 1.46/0.00, Took 5.53 sec
# Epoch 7, Acc(train/val): 51.36/46.95, Loss(train/val) 1.39/0.00, Took 5.69 sec
# Epoch 8, Acc(train/val): 53.14/47.67, Loss(train/val) 1.34/0.00, Took 5.60 sec
# Epoch 9, Acc(train/val): 53.45/46.21, Loss(train/val) 1.32/0.00, Took 5.67 sec
# Epoch 10, Acc(train/val): 54.03/47.84, Loss(train/val) 1.31/0.00, Took 5.43 sec
# Epoch 11, Acc(train/val): 55.16/47.66, Loss(train/val) 1.28/0.00, Took 5.41 sec
# Epoch 12, Acc(train/val): 55.96/48.29, Loss(train/val) 1.25/0.00, Took 5.50 sec
# Epoch 13, Acc(train/val): 57.13/47.86, Loss(train/val) 1.21/0.00, Took 5.40 sec
# Epoch 14, Acc(train/val): 56.30/46.79, Loss(train/val) 1.24/0.00, Took 5.57 sec
# Epoch 15, Acc(train/val): 57.13/47.85, Loss(train/val) 1.22/0.00, Took 5.97 sec
# Epoch 16, Acc(train/val): 59.10/49.55, Loss(train/val) 1.17/0.00, Took 5.57 sec
# Epoch 17, Acc(train/val): 60.39/49.08, Loss(train/val) 1.13/0.00, Took 5.62 sec
# Epoch 18, Acc(train/val): 60.67/49.52, Loss(train/val) 1.13/0.00, Took 5.65 sec
# Epoch 19, Acc(train/val): 61.72/50.54, Loss(train/val) 1.10/0.00, Took 5.75 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 33.83/39.16, Loss(train/val) 1.88/0.00, Took 5.45 sec
# Epoch 1, Acc(train/val): 40.85/38.23, Loss(train/val) 1.69/0.00, Took 5.78 sec
# Epoch 2, Acc(train/val): 41.38/40.34, Loss(train/val) 1.67/0.00, Took 5.51 sec
# Epoch 3, Acc(train/val): 43.49/40.95, Loss(train/val) 1.60/0.00, Took 5.77 sec
# Epoch 4, Acc(train/val): 46.30/42.11, Loss(train/val) 1.52/0.00, Took 5.53 sec
# Epoch 5, Acc(train/val): 47.69/45.00, Loss(train/val) 1.48/0.00, Took 5.43 sec
# Epoch 6, Acc(train/val): 50.56/47.93, Loss(train/val) 1.41/0.00, Took 5.59 sec
# Epoch 7, Acc(train/val): 52.16/45.70, Loss(train/val) 1.35/0.00, Took 5.62 sec
# Epoch 8, Acc(train/val): 52.28/46.04, Loss(train/val) 1.36/0.00, Took 5.61 sec
# Epoch 9, Acc(train/val): 52.77/47.83, Loss(train/val) 1.35/0.00, Took 5.37 sec
# Epoch 10, Acc(train/val): 54.67/47.60, Loss(train/val) 1.29/0.00, Took 5.39 sec
# Epoch 11, Acc(train/val): 55.94/48.16, Loss(train/val) 1.25/0.00, Took 5.60 sec
# Epoch 12, Acc(train/val): 57.09/47.85, Loss(train/val) 1.22/0.00, Took 5.48 sec
# Epoch 13, Acc(train/val): 57.64/47.16, Loss(train/val) 1.20/0.00, Took 5.47 sec
# Epoch 14, Acc(train/val): 58.34/48.05, Loss(train/val) 1.19/0.00, Took 5.61 sec
# Epoch 15, Acc(train/val): 59.56/50.66, Loss(train/val) 1.15/0.00, Took 5.76 sec
# Epoch 16, Acc(train/val): 62.35/49.50, Loss(train/val) 1.08/0.00, Took 5.76 sec
# Epoch 17, Acc(train/val): 62.61/50.79, Loss(train/val) 1.07/0.00, Took 5.65 sec
# Epoch 18, Acc(train/val): 64.46/51.00, Loss(train/val) 1.01/0.00, Took 5.68 sec
# Epoch 19, Acc(train/val): 65.78/49.34, Loss(train/val) 0.98/0.00, Took 5.64 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 24.78/33.93, Loss(train/val) 2.10/0.00, Took 5.71 sec
# Epoch 1, Acc(train/val): 35.81/39.15, Loss(train/val) 1.82/0.00, Took 5.47 sec
# Epoch 2, Acc(train/val): 39.56/40.11, Loss(train/val) 1.71/0.00, Took 5.50 sec
# Epoch 3, Acc(train/val): 41.36/41.92, Loss(train/val) 1.65/0.00, Took 5.64 sec
# Epoch 4, Acc(train/val): 42.98/43.10, Loss(train/val) 1.61/0.00, Took 5.92 sec
# Epoch 5, Acc(train/val): 44.91/43.95, Loss(train/val) 1.56/0.00, Took 5.87 sec
# Epoch 6, Acc(train/val): 46.03/44.29, Loss(train/val) 1.52/0.00, Took 5.60 sec
# Epoch 7, Acc(train/val): 46.41/44.90, Loss(train/val) 1.50/0.00, Took 5.76 sec
# Epoch 8, Acc(train/val): 47.72/45.89, Loss(train/val) 1.48/0.00, Took 5.69 sec
# Epoch 9, Acc(train/val): 48.08/45.22, Loss(train/val) 1.46/0.00, Took 5.76 sec
# Epoch 10, Acc(train/val): 48.89/45.82, Loss(train/val) 1.44/0.00, Took 5.51 sec
# Epoch 11, Acc(train/val): 49.09/45.58, Loss(train/val) 1.43/0.00, Took 5.81 sec
# Epoch 12, Acc(train/val): 50.00/47.17, Loss(train/val) 1.41/0.00, Took 5.94 sec
# Epoch 13, Acc(train/val): 51.01/46.55, Loss(train/val) 1.38/0.00, Took 5.66 sec
# Epoch 14, Acc(train/val): 51.96/46.39, Loss(train/val) 1.36/0.00, Took 5.85 sec
# Epoch 15, Acc(train/val): 51.86/46.76, Loss(train/val) 1.36/0.00, Took 5.55 sec
# Epoch 16, Acc(train/val): 52.49/47.58, Loss(train/val) 1.34/0.00, Took 5.84 sec
# Epoch 17, Acc(train/val): 53.01/47.20, Loss(train/val) 1.32/0.00, Took 5.78 sec
# Epoch 18, Acc(train/val): 54.01/47.62, Loss(train/val) 1.29/0.00, Took 6.04 sec
# Epoch 19, Acc(train/val): 53.99/46.09, Loss(train/val) 1.29/0.00, Took 6.28 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 28.50/37.76, Loss(train/val) 2.00/0.00, Took 5.68 sec
# Epoch 1, Acc(train/val): 39.23/41.34, Loss(train/val) 1.72/0.00, Took 5.72 sec
# Epoch 2, Acc(train/val): 42.34/42.81, Loss(train/val) 1.63/0.00, Took 5.84 sec
# Epoch 3, Acc(train/val): 44.01/43.21, Loss(train/val) 1.59/0.00, Took 5.94 sec
# Epoch 4, Acc(train/val): 45.76/45.10, Loss(train/val) 1.53/0.00, Took 5.76 sec
# Epoch 5, Acc(train/val): 47.29/46.69, Loss(train/val) 1.48/0.00, Took 5.77 sec
# Epoch 6, Acc(train/val): 49.67/46.10, Loss(train/val) 1.43/0.00, Took 5.68 sec
# Epoch 7, Acc(train/val): 49.88/45.97, Loss(train/val) 1.41/0.00, Took 5.69 sec
# Epoch 8, Acc(train/val): 50.32/46.68, Loss(train/val) 1.40/0.00, Took 5.83 sec
# Epoch 9, Acc(train/val): 51.33/45.81, Loss(train/val) 1.38/0.00, Took 5.76 sec
# Epoch 10, Acc(train/val): 51.74/46.68, Loss(train/val) 1.36/0.00, Took 5.66 sec
# Epoch 11, Acc(train/val): 52.49/48.30, Loss(train/val) 1.33/0.00, Took 5.44 sec
# Epoch 12, Acc(train/val): 53.80/48.52, Loss(train/val) 1.31/0.00, Took 5.82 sec
# Epoch 13, Acc(train/val): 55.59/49.69, Loss(train/val) 1.26/0.00, Took 5.88 sec
# Epoch 14, Acc(train/val): 56.11/47.80, Loss(train/val) 1.24/0.00, Took 5.93 sec
# Epoch 15, Acc(train/val): 55.28/47.16, Loss(train/val) 1.26/0.00, Took 5.68 sec
# Epoch 16, Acc(train/val): 55.94/47.73, Loss(train/val) 1.24/0.00, Took 5.56 sec
# Epoch 17, Acc(train/val): 56.82/49.43, Loss(train/val) 1.22/0.00, Took 5.61 sec
# Epoch 18, Acc(train/val): 57.26/49.18, Loss(train/val) 1.20/0.00, Took 6.00 sec
# Epoch 19, Acc(train/val): 58.82/49.93, Loss(train/val) 1.17/0.00, Took 5.98 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 29.52/39.10, Loss(train/val) 1.96/0.00, Took 6.17 sec
# Epoch 1, Acc(train/val): 40.12/40.02, Loss(train/val) 1.70/0.00, Took 5.99 sec
# Epoch 2, Acc(train/val): 42.39/41.66, Loss(train/val) 1.63/0.00, Took 6.19 sec
# Epoch 3, Acc(train/val): 44.38/41.52, Loss(train/val) 1.56/0.00, Took 6.01 sec
# Epoch 4, Acc(train/val): 45.40/42.53, Loss(train/val) 1.54/0.00, Took 6.04 sec
# Epoch 5, Acc(train/val): 46.36/44.66, Loss(train/val) 1.52/0.00, Took 6.02 sec
# Epoch 6, Acc(train/val): 48.93/46.74, Loss(train/val) 1.44/0.00, Took 6.06 sec
# Epoch 7, Acc(train/val): 50.79/46.53, Loss(train/val) 1.38/0.00, Took 6.28 sec
# Epoch 8, Acc(train/val): 51.19/46.29, Loss(train/val) 1.37/0.00, Took 5.89 sec
# Epoch 9, Acc(train/val): 51.76/47.59, Loss(train/val) 1.36/0.00, Took 6.41 sec
# Epoch 10, Acc(train/val): 53.30/48.59, Loss(train/val) 1.31/0.00, Took 6.10 sec
# Epoch 11, Acc(train/val): 55.00/47.39, Loss(train/val) 1.27/0.00, Took 6.37 sec
# Epoch 12, Acc(train/val): 54.81/47.02, Loss(train/val) 1.28/0.00, Took 5.84 sec
# Epoch 13, Acc(train/val): 55.67/47.97, Loss(train/val) 1.25/0.00, Took 5.85 sec
# Epoch 14, Acc(train/val): 56.91/47.31, Loss(train/val) 1.21/0.00, Took 6.00 sec
# Epoch 15, Acc(train/val): 56.40/48.56, Loss(train/val) 1.23/0.00, Took 6.29 sec
# Epoch 16, Acc(train/val): 58.15/48.73, Loss(train/val) 1.19/0.00, Took 6.10 sec
# Epoch 17, Acc(train/val): 60.04/49.79, Loss(train/val) 1.14/0.00, Took 6.00 sec
# Epoch 18, Acc(train/val): 60.46/50.32, Loss(train/val) 1.12/0.00, Took 5.93 sec
# Epoch 19, Acc(train/val): 61.66/49.07, Loss(train/val) 1.07/0.00, Took 5.78 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 31.73/38.33, Loss(train/val) 1.92/0.00, Took 5.71 sec
# Epoch 1, Acc(train/val): 38.56/38.27, Loss(train/val) 1.75/0.00, Took 5.98 sec
# Epoch 2, Acc(train/val): 41.11/38.43, Loss(train/val) 1.67/0.00, Took 6.04 sec
# Epoch 3, Acc(train/val): 42.30/40.38, Loss(train/val) 1.63/0.00, Took 5.92 sec
# Epoch 4, Acc(train/val): 44.15/43.07, Loss(train/val) 1.57/0.00, Took 5.87 sec
# Epoch 5, Acc(train/val): 47.30/43.80, Loss(train/val) 1.48/0.00, Took 6.11 sec
# Epoch 6, Acc(train/val): 48.64/44.65, Loss(train/val) 1.45/0.00, Took 6.10 sec
# Epoch 7, Acc(train/val): 48.77/44.55, Loss(train/val) 1.45/0.00, Took 6.13 sec
# Epoch 8, Acc(train/val): 50.98/46.36, Loss(train/val) 1.39/0.00, Took 6.05 sec
# Epoch 9, Acc(train/val): 52.77/47.39, Loss(train/val) 1.34/0.00, Took 6.12 sec
# Epoch 10, Acc(train/val): 54.36/47.35, Loss(train/val) 1.29/0.00, Took 6.29 sec
# Epoch 11, Acc(train/val): 55.45/47.99, Loss(train/val) 1.27/0.00, Took 6.13 sec
# Epoch 12, Acc(train/val): 54.94/47.71, Loss(train/val) 1.28/0.00, Took 5.91 sec
# Epoch 13, Acc(train/val): 56.33/47.56, Loss(train/val) 1.23/0.00, Took 5.87 sec
# Epoch 14, Acc(train/val): 57.05/47.79, Loss(train/val) 1.20/0.00, Took 5.84 sec
# Epoch 15, Acc(train/val): 58.27/46.16, Loss(train/val) 1.17/0.00, Took 5.79 sec
# Epoch 16, Acc(train/val): 59.05/47.36, Loss(train/val) 1.15/0.00, Took 6.05 sec
# Epoch 17, Acc(train/val): 59.42/48.66, Loss(train/val) 1.16/0.00, Took 5.85 sec
# Epoch 18, Acc(train/val): 61.88/49.45, Loss(train/val) 1.08/0.00, Took 5.87 sec
# Epoch 19, Acc(train/val): 63.73/49.50, Loss(train/val) 1.02/0.00, Took 6.03 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=10, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 14.29/21.95, Loss(train/val) 2.35/0.00, Took 6.17 sec
# Epoch 1, Acc(train/val): 22.49/29.22, Loss(train/val) 2.13/0.00, Took 6.30 sec
# Epoch 2, Acc(train/val): 28.72/33.91, Loss(train/val) 1.97/0.00, Took 6.15 sec
# Epoch 3, Acc(train/val): 32.66/35.59, Loss(train/val) 1.87/0.00, Took 6.03 sec
# Epoch 4, Acc(train/val): 34.64/37.81, Loss(train/val) 1.82/0.00, Took 6.31 sec
# Epoch 5, Acc(train/val): 36.70/38.13, Loss(train/val) 1.76/0.00, Took 6.25 sec
# Epoch 6, Acc(train/val): 37.41/38.99, Loss(train/val) 1.74/0.00, Took 6.22 sec
# Epoch 7, Acc(train/val): 38.76/40.15, Loss(train/val) 1.72/0.00, Took 6.32 sec
# Epoch 8, Acc(train/val): 40.94/42.18, Loss(train/val) 1.66/0.00, Took 6.20 sec
# Epoch 9, Acc(train/val): 42.49/42.45, Loss(train/val) 1.62/0.00, Took 6.16 sec
# Epoch 10, Acc(train/val): 42.97/41.28, Loss(train/val) 1.60/0.00, Took 6.19 sec
# Epoch 11, Acc(train/val): 43.10/42.17, Loss(train/val) 1.59/0.00, Took 6.29 sec
# Epoch 12, Acc(train/val): 43.56/41.05, Loss(train/val) 1.59/0.00, Took 6.18 sec
# Epoch 13, Acc(train/val): 43.82/43.86, Loss(train/val) 1.59/0.00, Took 6.12 sec
# Epoch 14, Acc(train/val): 45.64/43.32, Loss(train/val) 1.53/0.00, Took 6.18 sec
# Epoch 15, Acc(train/val): 45.88/43.99, Loss(train/val) 1.52/0.00, Took 6.11 sec
# Epoch 16, Acc(train/val): 46.20/41.97, Loss(train/val) 1.51/0.00, Took 6.29 sec
# Epoch 17, Acc(train/val): 46.59/44.99, Loss(train/val) 1.50/0.00, Took 6.25 sec
# Epoch 18, Acc(train/val): 47.65/43.38, Loss(train/val) 1.48/0.00, Took 6.25 sec
# Epoch 19, Acc(train/val): 47.70/44.75, Loss(train/val) 1.47/0.00, Took 6.22 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=10, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 17.18/25.75, Loss(train/val) 2.27/0.00, Took 6.24 sec
# Epoch 1, Acc(train/val): 27.15/33.44, Loss(train/val) 2.00/0.00, Took 6.09 sec
# Epoch 2, Acc(train/val): 32.97/35.90, Loss(train/val) 1.86/0.00, Took 5.99 sec
# Epoch 3, Acc(train/val): 35.71/37.87, Loss(train/val) 1.78/0.00, Took 6.31 sec
# Epoch 4, Acc(train/val): 36.80/36.83, Loss(train/val) 1.76/0.00, Took 6.23 sec
# Epoch 5, Acc(train/val): 37.20/39.87, Loss(train/val) 1.76/0.00, Took 6.30 sec
# Epoch 6, Acc(train/val): 40.26/41.65, Loss(train/val) 1.66/0.00, Took 6.45 sec
# Epoch 7, Acc(train/val): 42.49/42.00, Loss(train/val) 1.60/0.00, Took 6.40 sec
# Epoch 8, Acc(train/val): 43.37/40.94, Loss(train/val) 1.58/0.00, Took 6.31 sec
# Epoch 9, Acc(train/val): 43.31/41.95, Loss(train/val) 1.59/0.00, Took 6.10 sec
# Epoch 10, Acc(train/val): 43.95/43.07, Loss(train/val) 1.58/0.00, Took 6.27 sec
# Epoch 11, Acc(train/val): 45.67/42.93, Loss(train/val) 1.52/0.00, Took 6.32 sec
# Epoch 12, Acc(train/val): 47.16/43.62, Loss(train/val) 1.48/0.00, Took 6.45 sec
# Epoch 13, Acc(train/val): 47.48/43.44, Loss(train/val) 1.48/0.00, Took 6.07 sec
# Epoch 14, Acc(train/val): 47.49/43.39, Loss(train/val) 1.48/0.00, Took 6.17 sec
# Epoch 15, Acc(train/val): 47.85/44.36, Loss(train/val) 1.47/0.00, Took 5.93 sec
# Epoch 16, Acc(train/val): 48.94/45.36, Loss(train/val) 1.44/0.00, Took 6.13 sec
# Epoch 17, Acc(train/val): 49.81/45.84, Loss(train/val) 1.41/0.00, Took 6.40 sec
# Epoch 18, Acc(train/val): 50.63/46.47, Loss(train/val) 1.38/0.00, Took 6.26 sec
# Epoch 19, Acc(train/val): 50.93/45.96, Loss(train/val) 1.38/0.00, Took 6.49 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=10, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 19.52/29.54, Loss(train/val) 2.21/0.00, Took 6.65 sec
# Epoch 1, Acc(train/val): 30.83/35.16, Loss(train/val) 1.92/0.00, Took 6.49 sec
# Epoch 2, Acc(train/val): 35.19/36.81, Loss(train/val) 1.80/0.00, Took 6.41 sec
# Epoch 3, Acc(train/val): 37.44/36.49, Loss(train/val) 1.75/0.00, Took 6.55 sec
# Epoch 4, Acc(train/val): 37.50/37.77, Loss(train/val) 1.75/0.00, Took 6.50 sec
# Epoch 5, Acc(train/val): 38.60/38.92, Loss(train/val) 1.72/0.00, Took 6.50 sec
# Epoch 6, Acc(train/val): 41.47/40.41, Loss(train/val) 1.65/0.00, Took 6.51 sec
# Epoch 7, Acc(train/val): 42.17/40.47, Loss(train/val) 1.62/0.00, Took 6.35 sec
# Epoch 8, Acc(train/val): 43.04/42.23, Loss(train/val) 1.60/0.00, Took 6.58 sec
# Epoch 9, Acc(train/val): 44.74/42.88, Loss(train/val) 1.55/0.00, Took 6.10 sec
# Epoch 10, Acc(train/val): 46.10/43.26, Loss(train/val) 1.51/0.00, Took 6.34 sec
# Epoch 11, Acc(train/val): 46.99/42.98, Loss(train/val) 1.49/0.00, Took 6.30 sec
# Epoch 12, Acc(train/val): 47.15/43.80, Loss(train/val) 1.50/0.00, Took 6.20 sec
# Epoch 13, Acc(train/val): 48.76/45.10, Loss(train/val) 1.44/0.00, Took 6.59 sec
# Epoch 14, Acc(train/val): 50.11/43.69, Loss(train/val) 1.41/0.00, Took 6.69 sec
# Epoch 15, Acc(train/val): 49.10/45.67, Loss(train/val) 1.43/0.00, Took 6.38 sec
# Epoch 16, Acc(train/val): 51.19/46.23, Loss(train/val) 1.38/0.00, Took 6.79 sec
# Epoch 17, Acc(train/val): 52.28/45.98, Loss(train/val) 1.35/0.00, Took 6.61 sec
# Epoch 18, Acc(train/val): 52.59/45.49, Loss(train/val) 1.34/0.00, Took 6.43 sec
# Epoch 19, Acc(train/val): 52.10/45.13, Loss(train/val) 1.35/0.00, Took 6.45 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=10, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 21.95/32.47, Loss(train/val) 2.16/0.00, Took 6.44 sec
# Epoch 1, Acc(train/val): 32.09/35.49, Loss(train/val) 1.89/0.00, Took 6.21 sec
# Epoch 2, Acc(train/val): 35.38/36.54, Loss(train/val) 1.81/0.00, Took 6.14 sec
# Epoch 3, Acc(train/val): 36.93/35.66, Loss(train/val) 1.77/0.00, Took 6.36 sec
# Epoch 4, Acc(train/val): 38.02/39.57, Loss(train/val) 1.75/0.00, Took 6.28 sec
# Epoch 5, Acc(train/val): 39.37/38.03, Loss(train/val) 1.70/0.00, Took 6.31 sec
# Epoch 6, Acc(train/val): 41.29/39.92, Loss(train/val) 1.65/0.00, Took 6.42 sec
# Epoch 7, Acc(train/val): 42.35/41.35, Loss(train/val) 1.61/0.00, Took 6.41 sec
# Epoch 8, Acc(train/val): 45.09/42.86, Loss(train/val) 1.56/0.00, Took 6.39 sec
# Epoch 9, Acc(train/val): 46.09/43.37, Loss(train/val) 1.52/0.00, Took 6.30 sec
# Epoch 10, Acc(train/val): 47.00/42.95, Loss(train/val) 1.50/0.00, Took 6.33 sec
# Epoch 11, Acc(train/val): 48.17/44.97, Loss(train/val) 1.46/0.00, Took 6.20 sec
# Epoch 12, Acc(train/val): 49.14/43.22, Loss(train/val) 1.44/0.00, Took 6.27 sec
# Epoch 13, Acc(train/val): 49.24/44.18, Loss(train/val) 1.43/0.00, Took 6.21 sec
# Epoch 14, Acc(train/val): 50.95/45.97, Loss(train/val) 1.39/0.00, Took 6.15 sec
# Epoch 15, Acc(train/val): 52.27/45.14, Loss(train/val) 1.36/0.00, Took 6.26 sec
# Epoch 16, Acc(train/val): 51.47/44.01, Loss(train/val) 1.37/0.00, Took 6.28 sec
# Epoch 17, Acc(train/val): 52.27/45.12, Loss(train/val) 1.34/0.00, Took 6.07 sec
# Epoch 18, Acc(train/val): 53.19/43.62, Loss(train/val) 1.32/0.00, Took 6.07 sec
# Epoch 19, Acc(train/val): 52.60/44.69, Loss(train/val) 1.34/0.00, Took 6.16 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=20, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.39/10.44, Loss(train/val) 2.44/0.00, Took 7.13 sec
# Epoch 1, Acc(train/val): 10.49/10.68, Loss(train/val) 2.40/0.00, Took 6.93 sec
# Epoch 2, Acc(train/val): 10.90/10.53, Loss(train/val) 2.37/0.00, Took 7.01 sec
# Epoch 3, Acc(train/val): 11.81/12.10, Loss(train/val) 2.35/0.00, Took 6.95 sec
# Epoch 4, Acc(train/val): 12.53/14.81, Loss(train/val) 2.32/0.00, Took 7.07 sec
# Epoch 5, Acc(train/val): 13.96/16.65, Loss(train/val) 2.28/0.00, Took 7.07 sec
# Epoch 6, Acc(train/val): 15.57/18.44, Loss(train/val) 2.23/0.00, Took 6.94 sec
# Epoch 7, Acc(train/val): 16.79/19.92, Loss(train/val) 2.20/0.00, Took 7.12 sec
# Epoch 8, Acc(train/val): 17.89/21.24, Loss(train/val) 2.16/0.00, Took 7.11 sec
# Epoch 9, Acc(train/val): 19.07/22.02, Loss(train/val) 2.13/0.00, Took 7.02 sec
# Epoch 10, Acc(train/val): 20.28/22.62, Loss(train/val) 2.10/0.00, Took 7.12 sec
# Epoch 11, Acc(train/val): 20.95/23.53, Loss(train/val) 2.08/0.00, Took 6.95 sec
# Epoch 12, Acc(train/val): 22.36/25.57, Loss(train/val) 2.05/0.00, Took 6.97 sec
# Epoch 13, Acc(train/val): 23.57/25.77, Loss(train/val) 2.02/0.00, Took 6.99 sec
# Epoch 14, Acc(train/val): 24.80/27.07, Loss(train/val) 1.99/0.00, Took 6.93 sec
# Epoch 15, Acc(train/val): 25.39/27.58, Loss(train/val) 1.97/0.00, Took 7.00 sec
# Epoch 16, Acc(train/val): 26.06/28.73, Loss(train/val) 1.96/0.00, Took 7.14 sec
# Epoch 17, Acc(train/val): 27.67/29.96, Loss(train/val) 1.93/0.00, Took 7.08 sec
# Epoch 18, Acc(train/val): 28.38/30.36, Loss(train/val) 1.91/0.00, Took 6.93 sec
# Epoch 19, Acc(train/val): 29.40/32.23, Loss(train/val) 1.89/0.00, Took 6.87 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=20, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.58/10.48, Loss(train/val) 2.43/0.00, Took 6.87 sec
# Epoch 1, Acc(train/val): 11.01/11.86, Loss(train/val) 2.38/0.00, Took 7.06 sec
# Epoch 2, Acc(train/val): 11.82/12.37, Loss(train/val) 2.35/0.00, Took 6.99 sec
# Epoch 3, Acc(train/val): 14.39/17.73, Loss(train/val) 2.29/0.00, Took 6.87 sec
# Epoch 4, Acc(train/val): 16.28/18.39, Loss(train/val) 2.22/0.00, Took 6.84 sec
# Epoch 5, Acc(train/val): 18.39/22.12, Loss(train/val) 2.17/0.00, Took 6.93 sec
# Epoch 6, Acc(train/val): 19.98/21.87, Loss(train/val) 2.13/0.00, Took 7.06 sec
# Epoch 7, Acc(train/val): 21.30/23.68, Loss(train/val) 2.09/0.00, Took 6.91 sec
# Epoch 8, Acc(train/val): 22.61/24.01, Loss(train/val) 2.05/0.00, Took 6.94 sec
# Epoch 9, Acc(train/val): 24.26/26.70, Loss(train/val) 2.01/0.00, Took 7.11 sec
# Epoch 10, Acc(train/val): 25.95/27.67, Loss(train/val) 1.99/0.00, Took 7.01 sec
# Epoch 11, Acc(train/val): 26.99/29.37, Loss(train/val) 1.96/0.00, Took 6.83 sec
# Epoch 12, Acc(train/val): 27.91/29.51, Loss(train/val) 1.93/0.00, Took 6.95 sec
# Epoch 13, Acc(train/val): 29.56/30.20, Loss(train/val) 1.90/0.00, Took 7.05 sec
# Epoch 14, Acc(train/val): 31.06/32.09, Loss(train/val) 1.87/0.00, Took 7.02 sec
# Epoch 15, Acc(train/val): 31.70/31.05, Loss(train/val) 1.86/0.00, Took 6.89 sec
# Epoch 16, Acc(train/val): 32.16/31.94, Loss(train/val) 1.85/0.00, Took 6.96 sec
# Epoch 17, Acc(train/val): 32.68/32.68, Loss(train/val) 1.85/0.00, Took 6.95 sec
# Epoch 18, Acc(train/val): 32.28/33.69, Loss(train/val) 1.85/0.00, Took 6.90 sec
# Epoch 19, Acc(train/val): 34.44/35.08, Loss(train/val) 1.80/0.00, Took 6.93 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=20, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.67/10.44, Loss(train/val) 2.43/0.00, Took 6.92 sec
# Epoch 1, Acc(train/val): 11.68/12.37, Loss(train/val) 2.37/0.00, Took 6.80 sec
# Epoch 2, Acc(train/val): 14.18/16.63, Loss(train/val) 2.30/0.00, Took 7.01 sec
# Epoch 3, Acc(train/val): 16.77/19.03, Loss(train/val) 2.22/0.00, Took 7.15 sec
# Epoch 4, Acc(train/val): 18.73/19.99, Loss(train/val) 2.16/0.00, Took 6.77 sec
# Epoch 5, Acc(train/val): 20.56/24.47, Loss(train/val) 2.12/0.00, Took 6.93 sec
# Epoch 6, Acc(train/val): 23.09/26.34, Loss(train/val) 2.06/0.00, Took 6.78 sec
# Epoch 7, Acc(train/val): 25.11/26.33, Loss(train/val) 2.02/0.00, Took 6.82 sec
# Epoch 8, Acc(train/val): 26.82/28.91, Loss(train/val) 1.99/0.00, Took 7.03 sec
# Epoch 9, Acc(train/val): 27.57/30.61, Loss(train/val) 1.98/0.00, Took 7.03 sec
# Epoch 10, Acc(train/val): 29.57/31.40, Loss(train/val) 1.93/0.00, Took 6.81 sec
# Epoch 11, Acc(train/val): 30.82/32.20, Loss(train/val) 1.89/0.00, Took 6.87 sec
# Epoch 12, Acc(train/val): 32.21/33.23, Loss(train/val) 1.87/0.00, Took 6.89 sec
# Epoch 13, Acc(train/val): 32.66/34.05, Loss(train/val) 1.84/0.00, Took 6.77 sec
# Epoch 14, Acc(train/val): 33.52/33.59, Loss(train/val) 1.83/0.00, Took 6.89 sec
# Epoch 15, Acc(train/val): 34.14/34.08, Loss(train/val) 1.81/0.00, Took 6.85 sec
# Epoch 16, Acc(train/val): 35.02/33.53, Loss(train/val) 1.81/0.00, Took 6.61 sec
# Epoch 17, Acc(train/val): 34.53/36.17, Loss(train/val) 1.81/0.00, Took 6.76 sec
# Epoch 18, Acc(train/val): 36.45/36.62, Loss(train/val) 1.77/0.00, Took 6.68 sec
# Epoch 19, Acc(train/val): 37.59/37.94, Loss(train/val) 1.74/0.00, Took 7.27 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=20, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 11.12/11.93, Loss(train/val) 2.42/0.00, Took 7.14 sec
# Epoch 1, Acc(train/val): 13.23/16.90, Loss(train/val) 2.34/0.00, Took 7.26 sec
# Epoch 2, Acc(train/val): 17.39/22.20, Loss(train/val) 2.22/0.00, Took 7.50 sec
# Epoch 3, Acc(train/val): 20.64/24.20, Loss(train/val) 2.14/0.00, Took 7.23 sec
# Epoch 4, Acc(train/val): 22.89/24.97, Loss(train/val) 2.09/0.00, Took 7.42 sec
# Epoch 5, Acc(train/val): 23.58/26.16, Loss(train/val) 2.08/0.00, Took 7.46 sec
# Epoch 6, Acc(train/val): 24.69/28.64, Loss(train/val) 2.06/0.00, Took 7.25 sec
# Epoch 7, Acc(train/val): 27.47/29.91, Loss(train/val) 1.99/0.00, Took 7.24 sec
# Epoch 8, Acc(train/val): 30.63/32.60, Loss(train/val) 1.92/0.00, Took 7.19 sec
# Epoch 9, Acc(train/val): 31.13/31.86, Loss(train/val) 1.89/0.00, Took 7.23 sec
# Epoch 10, Acc(train/val): 31.39/32.66, Loss(train/val) 1.88/0.00, Took 7.33 sec
# Epoch 11, Acc(train/val): 32.08/32.04, Loss(train/val) 1.89/0.00, Took 7.14 sec
# Epoch 12, Acc(train/val): 33.48/35.94, Loss(train/val) 1.84/0.00, Took 7.13 sec
# Epoch 13, Acc(train/val): 35.62/32.21, Loss(train/val) 1.79/0.00, Took 7.13 sec
# Epoch 14, Acc(train/val): 35.10/34.08, Loss(train/val) 1.79/0.00, Took 7.20 sec
# Epoch 15, Acc(train/val): 34.84/35.60, Loss(train/val) 1.81/0.00, Took 7.31 sec
# Epoch 16, Acc(train/val): 37.78/38.59, Loss(train/val) 1.75/0.00, Took 6.83 sec
# Epoch 17, Acc(train/val): 39.70/38.21, Loss(train/val) 1.68/0.00, Took 6.68 sec
# Epoch 18, Acc(train/val): 40.11/38.31, Loss(train/val) 1.67/0.00, Took 6.72 sec
# Epoch 19, Acc(train/val): 40.19/37.31, Loss(train/val) 1.69/0.00, Took 6.79 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=50, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.04/9.96, Loss(train/val) 2.44/0.00, Took 9.30 sec
# Epoch 1, Acc(train/val): 9.91/10.36, Loss(train/val) 2.41/0.00, Took 9.18 sec
# Epoch 2, Acc(train/val): 9.77/9.47, Loss(train/val) 2.39/0.00, Took 9.90 sec
# Epoch 3, Acc(train/val): 10.02/9.80, Loss(train/val) 2.38/0.00, Took 9.21 sec
# Epoch 4, Acc(train/val): 9.77/10.23, Loss(train/val) 2.37/0.00, Took 9.40 sec
# Epoch 5, Acc(train/val): 10.04/10.10, Loss(train/val) 2.36/0.00, Took 9.88 sec
# Epoch 6, Acc(train/val): 10.19/10.25, Loss(train/val) 2.36/0.00, Took 9.49 sec
# Epoch 7, Acc(train/val): 10.29/9.66, Loss(train/val) 2.35/0.00, Took 9.82 sec
# Epoch 8, Acc(train/val): 9.99/10.85, Loss(train/val) 2.35/0.00, Took 9.23 sec
# Epoch 9, Acc(train/val): 10.12/10.21, Loss(train/val) 2.35/0.00, Took 8.76 sec
# Epoch 10, Acc(train/val): 9.90/10.49, Loss(train/val) 2.34/0.00, Took 8.48 sec
# Epoch 11, Acc(train/val): 9.90/9.67, Loss(train/val) 2.34/0.00, Took 8.93 sec
# Epoch 12, Acc(train/val): 10.27/9.81, Loss(train/val) 2.34/0.00, Took 9.37 sec
# Epoch 13, Acc(train/val): 9.90/10.18, Loss(train/val) 2.34/0.00, Took 9.18 sec
# Epoch 14, Acc(train/val): 9.90/10.50, Loss(train/val) 2.33/0.00, Took 9.32 sec
# Epoch 15, Acc(train/val): 9.92/9.96, Loss(train/val) 2.33/0.00, Took 9.21 sec
# Epoch 16, Acc(train/val): 10.10/10.26, Loss(train/val) 2.33/0.00, Took 9.37 sec
# Epoch 17, Acc(train/val): 9.92/10.13, Loss(train/val) 2.33/0.00, Took 9.44 sec
# Epoch 18, Acc(train/val): 9.99/10.34, Loss(train/val) 2.33/0.00, Took 9.63 sec
# Epoch 19, Acc(train/val): 10.12/9.86, Loss(train/val) 2.33/0.00, Took 9.27 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=50, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.38/10.39, Loss(train/val) 2.43/0.00, Took 9.47 sec
# Epoch 1, Acc(train/val): 10.03/9.65, Loss(train/val) 2.39/0.00, Took 9.63 sec
# Epoch 2, Acc(train/val): 10.02/9.91, Loss(train/val) 2.38/0.00, Took 9.37 sec
# Epoch 3, Acc(train/val): 9.81/10.29, Loss(train/val) 2.37/0.00, Took 9.74 sec
# Epoch 4, Acc(train/val): 10.07/9.92, Loss(train/val) 2.36/0.00, Took 9.53 sec
# Epoch 5, Acc(train/val): 10.20/10.31, Loss(train/val) 2.36/0.00, Took 9.38 sec
# Epoch 6, Acc(train/val): 9.95/9.68, Loss(train/val) 2.36/0.00, Took 10.08 sec
# Epoch 7, Acc(train/val): 10.09/10.28, Loss(train/val) 2.35/0.00, Took 9.26 sec
# Epoch 8, Acc(train/val): 10.21/9.90, Loss(train/val) 2.35/0.00, Took 9.41 sec
# Epoch 9, Acc(train/val): 10.17/10.22, Loss(train/val) 2.35/0.00, Took 9.07 sec
# Epoch 10, Acc(train/val): 9.96/9.71, Loss(train/val) 2.34/0.00, Took 9.49 sec
# Epoch 11, Acc(train/val): 10.10/9.77, Loss(train/val) 2.34/0.00, Took 9.85 sec
# Epoch 12, Acc(train/val): 9.89/10.01, Loss(train/val) 2.34/0.00, Took 9.54 sec
# Epoch 13, Acc(train/val): 10.01/9.63, Loss(train/val) 2.34/0.00, Took 9.32 sec
# Epoch 14, Acc(train/val): 10.04/10.06, Loss(train/val) 2.33/0.00, Took 8.95 sec
# Epoch 15, Acc(train/val): 10.09/9.81, Loss(train/val) 2.33/0.00, Took 8.79 sec
# Epoch 16, Acc(train/val): 10.04/9.80, Loss(train/val) 2.33/0.00, Took 9.22 sec
# Epoch 17, Acc(train/val): 10.10/10.11, Loss(train/val) 2.33/0.00, Took 9.25 sec
# Epoch 18, Acc(train/val): 10.47/9.82, Loss(train/val) 2.33/0.00, Took 9.50 sec
# Epoch 19, Acc(train/val): 10.01/10.24, Loss(train/val) 2.33/0.00, Took 10.00 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=50, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.18/9.81, Loss(train/val) 2.44/0.00, Took 9.66 sec
# Epoch 1, Acc(train/val): 9.90/9.39, Loss(train/val) 2.40/0.00, Took 9.36 sec
# Epoch 2, Acc(train/val): 9.96/9.80, Loss(train/val) 2.38/0.00, Took 9.25 sec
# Epoch 3, Acc(train/val): 10.11/10.38, Loss(train/val) 2.37/0.00, Took 9.75 sec
# Epoch 4, Acc(train/val): 10.03/9.74, Loss(train/val) 2.37/0.00, Took 9.71 sec
# Epoch 5, Acc(train/val): 10.02/9.85, Loss(train/val) 2.37/0.00, Took 9.39 sec
# Epoch 6, Acc(train/val): 10.32/9.90, Loss(train/val) 2.36/0.00, Took 9.17 sec
# Epoch 7, Acc(train/val): 9.93/10.07, Loss(train/val) 2.36/0.00, Took 9.27 sec
# Epoch 8, Acc(train/val): 9.80/9.87, Loss(train/val) 2.36/0.00, Took 9.39 sec
# Epoch 9, Acc(train/val): 10.28/9.09, Loss(train/val) 2.35/0.00, Took 9.36 sec
# Epoch 10, Acc(train/val): 10.24/10.26, Loss(train/val) 2.34/0.00, Took 9.67 sec
# Epoch 11, Acc(train/val): 10.09/10.02, Loss(train/val) 2.34/0.00, Took 9.53 sec
# Epoch 12, Acc(train/val): 9.88/9.93, Loss(train/val) 2.34/0.00, Took 9.12 sec
# Epoch 13, Acc(train/val): 10.09/10.10, Loss(train/val) 2.34/0.00, Took 9.39 sec
# Epoch 14, Acc(train/val): 10.02/10.34, Loss(train/val) 2.34/0.00, Took 9.09 sec
# Epoch 15, Acc(train/val): 10.30/10.02, Loss(train/val) 2.33/0.00, Took 9.12 sec
# Epoch 16, Acc(train/val): 9.67/9.86, Loss(train/val) 2.33/0.00, Took 9.41 sec
# Epoch 17, Acc(train/val): 9.90/9.75, Loss(train/val) 2.33/0.00, Took 9.34 sec
# Epoch 18, Acc(train/val): 9.95/9.98, Loss(train/val) 2.34/0.00, Took 9.42 sec
# Epoch 19, Acc(train/val): 10.07/10.44, Loss(train/val) 2.33/0.00, Took 8.98 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=50, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.19/10.14, Loss(train/val) 2.43/0.00, Took 9.69 sec
# Epoch 1, Acc(train/val): 10.21/9.68, Loss(train/val) 2.39/0.00, Took 9.53 sec
# Epoch 2, Acc(train/val): 10.27/10.35, Loss(train/val) 2.38/0.00, Took 9.33 sec
# Epoch 3, Acc(train/val): 10.21/10.07, Loss(train/val) 2.37/0.00, Took 9.41 sec
# Epoch 4, Acc(train/val): 10.35/9.96, Loss(train/val) 2.37/0.00, Took 9.04 sec
# Epoch 5, Acc(train/val): 10.19/9.81, Loss(train/val) 2.37/0.00, Took 8.89 sec
# Epoch 6, Acc(train/val): 9.95/10.48, Loss(train/val) 2.35/0.00, Took 9.60 sec
# Epoch 7, Acc(train/val): 9.94/9.93, Loss(train/val) 2.35/0.00, Took 9.66 sec
# Epoch 8, Acc(train/val): 10.05/9.91, Loss(train/val) 2.35/0.00, Took 9.26 sec
# Epoch 9, Acc(train/val): 10.36/10.25, Loss(train/val) 2.35/0.00, Took 9.88 sec
# Epoch 10, Acc(train/val): 9.97/10.21, Loss(train/val) 2.36/0.00, Took 9.23 sec
# Epoch 11, Acc(train/val): 9.82/10.26, Loss(train/val) 2.36/0.00, Took 8.99 sec
# Epoch 12, Acc(train/val): 10.04/10.38, Loss(train/val) 2.34/0.00, Took 9.61 sec
# Epoch 13, Acc(train/val): 9.81/9.79, Loss(train/val) 2.35/0.00, Took 9.22 sec
# Epoch 14, Acc(train/val): 10.09/9.79, Loss(train/val) 2.34/0.00, Took 9.56 sec
# Epoch 15, Acc(train/val): 10.21/10.49, Loss(train/val) 2.34/0.00, Took 9.33 sec
# Epoch 16, Acc(train/val): 9.92/10.16, Loss(train/val) 2.34/0.00, Took 9.74 sec
# Epoch 17, Acc(train/val): 10.08/10.19, Loss(train/val) 2.33/0.00, Took 9.57 sec
# Epoch 18, Acc(train/val): 10.29/10.47, Loss(train/val) 2.33/0.00, Took 9.91 sec
# Epoch 19, Acc(train/val): 10.34/10.12, Loss(train/val) 2.33/0.00, Took 9.49 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=300, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=100, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.02/10.25, Loss(train/val) 2.44/0.00, Took 14.13 sec
# Epoch 1, Acc(train/val): 9.93/9.84, Loss(train/val) 2.40/0.00, Took 15.11 sec
# Epoch 2, Acc(train/val): 9.79/9.79, Loss(train/val) 2.38/0.00, Took 15.01 sec
# Epoch 3, Acc(train/val): 9.87/9.82, Loss(train/val) 2.38/0.00, Took 14.78 sec
# Epoch 4, Acc(train/val): 10.07/10.11, Loss(train/val) 2.37/0.00, Took 14.94 sec
# Epoch 5, Acc(train/val): 10.06/9.85, Loss(train/val) 2.36/0.00, Took 14.88 sec
# Epoch 6, Acc(train/val): 10.16/9.91, Loss(train/val) 2.35/0.00, Took 14.38 sec
# Epoch 7, Acc(train/val): 9.90/9.91, Loss(train/val) 2.35/0.00, Took 15.18 sec
# Epoch 8, Acc(train/val): 9.98/10.32, Loss(train/val) 2.35/0.00, Took 15.20 sec
# Epoch 9, Acc(train/val): 9.98/10.20, Loss(train/val) 2.34/0.00, Took 15.05 sec
# Epoch 10, Acc(train/val): 10.01/10.06, Loss(train/val) 2.34/0.00, Took 14.72 sec
# Epoch 11, Acc(train/val): 9.99/9.97, Loss(train/val) 2.34/0.00, Took 14.65 sec
# Epoch 12, Acc(train/val): 10.01/9.61, Loss(train/val) 2.34/0.00, Took 14.69 sec
# Epoch 13, Acc(train/val): 10.07/9.92, Loss(train/val) 2.34/0.00, Took 14.83 sec
# Epoch 14, Acc(train/val): 9.96/9.69, Loss(train/val) 2.33/0.00, Took 14.75 sec
# Epoch 15, Acc(train/val): 10.07/10.35, Loss(train/val) 2.33/0.00, Took 14.66 sec
# Epoch 16, Acc(train/val): 9.93/9.77, Loss(train/val) 2.33/0.00, Took 14.65 sec
# Epoch 17, Acc(train/val): 10.17/10.65, Loss(train/val) 2.33/0.00, Took 14.60 sec
# Epoch 18, Acc(train/val): 10.30/10.18, Loss(train/val) 2.33/0.00, Took 15.15 sec
# Epoch 19, Acc(train/val): 9.78/9.59, Loss(train/val) 2.33/0.00, Took 15.12 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=500, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=100, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 9.85/10.05, Loss(train/val) 2.44/0.00, Took 14.97 sec
# Epoch 1, Acc(train/val): 10.16/9.86, Loss(train/val) 2.39/0.00, Took 15.07 sec
# Epoch 2, Acc(train/val): 10.30/10.35, Loss(train/val) 2.38/0.00, Took 14.72 sec
# Epoch 3, Acc(train/val): 10.29/10.09, Loss(train/val) 2.37/0.00, Took 14.14 sec
# Epoch 4, Acc(train/val): 9.95/9.67, Loss(train/val) 2.36/0.00, Took 14.84 sec
# Epoch 5, Acc(train/val): 9.93/10.33, Loss(train/val) 2.36/0.00, Took 15.45 sec
# Epoch 6, Acc(train/val): 9.85/9.69, Loss(train/val) 2.36/0.00, Took 14.50 sec
# Epoch 7, Acc(train/val): 10.16/10.22, Loss(train/val) 2.35/0.00, Took 15.03 sec
# Epoch 8, Acc(train/val): 9.92/9.08, Loss(train/val) 2.35/0.00, Took 14.35 sec
# Epoch 9, Acc(train/val): 9.81/10.37, Loss(train/val) 2.35/0.00, Took 15.19 sec
# Epoch 10, Acc(train/val): 10.04/9.93, Loss(train/val) 2.34/0.00, Took 14.74 sec
# Epoch 11, Acc(train/val): 10.18/10.09, Loss(train/val) 2.34/0.00, Took 14.88 sec
# Epoch 12, Acc(train/val): 9.98/9.94, Loss(train/val) 2.33/0.00, Took 14.51 sec
# Epoch 13, Acc(train/val): 10.20/10.36, Loss(train/val) 2.33/0.00, Took 14.33 sec
# Epoch 14, Acc(train/val): 10.06/10.09, Loss(train/val) 2.34/0.00, Took 14.80 sec
# Epoch 15, Acc(train/val): 10.05/10.16, Loss(train/val) 2.34/0.00, Took 14.58 sec
# Epoch 16, Acc(train/val): 10.08/10.01, Loss(train/val) 2.33/0.00, Took 14.77 sec
# Epoch 17, Acc(train/val): 10.30/9.86, Loss(train/val) 2.33/0.00, Took 14.70 sec
# Epoch 18, Acc(train/val): 10.07/9.90, Loss(train/val) 2.33/0.00, Took 14.86 sec
# Epoch 19, Acc(train/val): 10.27/9.64, Loss(train/val) 2.33/0.00, Took 14.66 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=700, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=100, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 10.02/10.00, Loss(train/val) 2.43/0.00, Took 15.29 sec
# Epoch 1, Acc(train/val): 9.99/9.55, Loss(train/val) 2.39/0.00, Took 14.64 sec
# Epoch 2, Acc(train/val): 10.07/10.41, Loss(train/val) 2.38/0.00, Took 14.99 sec
# Epoch 3, Acc(train/val): 10.18/10.08, Loss(train/val) 2.37/0.00, Took 14.63 sec
# Epoch 4, Acc(train/val): 10.18/10.45, Loss(train/val) 2.36/0.00, Took 14.59 sec
# Epoch 5, Acc(train/val): 9.89/9.60, Loss(train/val) 2.36/0.00, Took 14.58 sec
# Epoch 6, Acc(train/val): 9.84/9.92, Loss(train/val) 2.36/0.00, Took 14.96 sec
# Epoch 7, Acc(train/val): 10.12/9.78, Loss(train/val) 2.35/0.00, Took 15.09 sec
# Epoch 8, Acc(train/val): 10.05/9.68, Loss(train/val) 2.35/0.00, Took 14.72 sec
# Epoch 9, Acc(train/val): 9.95/9.75, Loss(train/val) 2.35/0.00, Took 14.46 sec
# Epoch 10, Acc(train/val): 9.90/9.31, Loss(train/val) 2.35/0.00, Took 14.90 sec
# Epoch 11, Acc(train/val): 10.29/9.87, Loss(train/val) 2.35/0.00, Took 15.19 sec
# Epoch 12, Acc(train/val): 9.86/9.95, Loss(train/val) 2.34/0.00, Took 14.59 sec
# Epoch 13, Acc(train/val): 10.10/9.75, Loss(train/val) 2.34/0.00, Took 14.95 sec
# Epoch 14, Acc(train/val): 10.09/10.36, Loss(train/val) 2.34/0.00, Took 15.35 sec
# Epoch 15, Acc(train/val): 10.01/9.79, Loss(train/val) 2.34/0.00, Took 15.08 sec
# Epoch 16, Acc(train/val): 10.16/9.98, Loss(train/val) 2.33/0.00, Took 14.41 sec
# Epoch 17, Acc(train/val): 9.97/10.34, Loss(train/val) 2.34/0.00, Took 14.47 sec
# Epoch 18, Acc(train/val): 10.08/9.32, Loss(train/val) 2.33/0.00, Took 15.25 sec
# Epoch 19, Acc(train/val): 10.13/10.05, Loss(train/val) 2.33/0.00, Took 15.07 sec
# Namespace(act='relu', dropout=0.1, epoch=20, hid_dim=1000, in_dim=3072, l2=1e-05, lr=1e-05, n_layer=100, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 9.80/10.32, Loss(train/val) 2.44/0.00, Took 14.95 sec
# Epoch 1, Acc(train/val): 10.07/9.98, Loss(train/val) 2.40/0.00, Took 15.34 sec
# Epoch 2, Acc(train/val): 9.94/9.67, Loss(train/val) 2.38/0.00, Took 15.68 sec
# Epoch 3, Acc(train/val): 10.05/10.16, Loss(train/val) 2.37/0.00, Took 14.84 sec
# Epoch 4, Acc(train/val): 9.80/9.88, Loss(train/val) 2.38/0.00, Took 14.74 sec
# Epoch 5, Acc(train/val): 10.08/9.85, Loss(train/val) 2.37/0.00, Took 15.22 sec
# Epoch 6, Acc(train/val): 9.84/10.16, Loss(train/val) 2.37/0.00, Took 15.06 sec
# Epoch 7, Acc(train/val): 10.12/10.17, Loss(train/val) 2.36/0.00, Took 15.46 sec
# Epoch 8, Acc(train/val): 10.07/10.19, Loss(train/val) 2.36/0.00, Took 15.19 sec
# Epoch 9, Acc(train/val): 10.21/10.38, Loss(train/val) 2.35/0.00, Took 14.78 sec
# Epoch 10, Acc(train/val): 10.14/10.10, Loss(train/val) 2.34/0.00, Took 14.93 sec
# Epoch 11, Acc(train/val): 9.92/9.82, Loss(train/val) 2.35/0.00, Took 14.72 sec
# Epoch 12, Acc(train/val): 10.03/10.37, Loss(train/val) 2.34/0.00, Took 15.11 sec
# Epoch 13, Acc(train/val): 9.86/9.91, Loss(train/val) 2.34/0.00, Took 15.02 sec
# Epoch 14, Acc(train/val): 10.09/10.02, Loss(train/val) 2.33/0.00, Took 14.83 sec
# Epoch 15, Acc(train/val): 10.11/9.60, Loss(train/val) 2.34/0.00, Took 14.89 sec
# Epoch 16, Acc(train/val): 10.24/9.79, Loss(train/val) 2.34/0.00, Took 15.59 sec
# Epoch 17, Acc(train/val): 10.05/9.92, Loss(train/val) 2.33/0.00, Took 14.68 sec
# Epoch 18, Acc(train/val): 9.67/10.16, Loss(train/val) 2.33/0.00, Took 15.38 sec
# Epoch 19, Acc(train/val): 9.92/10.02, Loss(train/val) 2.33/0.00, Took 15.07 sec
# '\n##### Optimizer만 변경해도 성능이 폭발적으로 증가할까? #####\n\n'

# %% [markdown]
# ## 실험 결과
# * 레이어의 개수와 뉴런의 개수를 변경해가며 실험 진행
#     * 가설
#         * Layer의 개수와 Neuron의 개수가 증가할수록 학습이 더 잘 진행될까?
#     * 실험 조건
#         * name_var1 = 'n_layer'
#         * name_var2 = 'hid_dim'
#         * list_var1 = [3, 5, 10, 20, 50, 100]
#         * list_var2 = [300, 500, 700, 1000]
#     * 실험 결과
#         * 이상적으로 레이어를 가장 많이 쌓고(100) 뉴런의 개수도 가장 많이 했을 때(1000) 결과가 가장 좋을 것 같았지만 실제 실험결과 3개의 레이어 700개의 뉴런의 결과가 가장 좋았다<code>(50.54%)</code>(하지만 정확도가 절반에 불가하다...!)
#     * Future Work
#         * 앞으로 다룰 Neural Network 등 한 단계 발전한 알고리즘을 적용해보고 결과를 비교해보자!
